# %%
import numpy as np 
import pandas as pd 
import os
import cv2

# %% [markdown]
# ## Labels

# %%
labels = os.listdir(r"archive\train")

# %%
labels
# Out:
# ['Closed', 'no_yawn', 'Open', 'yawn']

# %% [markdown]
# ## Visualize A random image

# %%
import matplotlib.pyplot as plt
plt.imshow(plt.imread(r"archive\train\Closed\_0.jpg"))

# %% [markdown]
# ## Image array

# %%
a = plt.imread(r"archive\train\yawn\10.jpg")

# %% [markdown]
# ## Image shape

# %%
a.shape
# Out:
# (480, 640, 3)

# %% [markdown]
# ## Visualize yawn image(Background is unnecessary. We need only face image array)

# %%
plt.imshow(plt.imread(r"archive\train\yawn\10.jpg"))

# %% [markdown]
# ## Take only face(For yawn and not_yawn)

# %%
import dlib
def face_for_yawn():
    
    direc="archive/train/"
    face_cas_path = "haarcascade_frontalface_default.xml"

    
    yaw_no = []
    IMG_SIZE = 145
    categories = ["yawn", "no_yawn"]
    
    for category in categories:
        path_link = os.path.join(direc, category)
        class_num1 = categories.index(category)
        print(class_num1)
        for image in os.listdir(path_link):
            image_array = cv2.imread(os.path.join(path_link, image), cv2.IMREAD_COLOR)
            face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
            faces = face_cascade.detectMultiScale(image_array, 1.3, 5)
            predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")
            for (x, y, w, h) in faces:
                landmarks = predictor(image_array, dlib.rectangle(x,y,x+w,y+h))
                mouth_points = landmarks.parts()[48:68]
                mouth_points_array = []
                for point in mouth_points:
                    mouth_points_array.append((point.x, point.y))
                mouth_points_array = np.array(mouth_points_array, dtype=np.int32)
                
                 # Get the bounding rectangle around the mouth region
                x1, y1 = np.min(mouth_points_array, axis=0)
                x2, y2 = np.max(mouth_points_array, axis=0)
                
                mouth_img = image_array[y1:y2, x1:x2]
                
                if mouth_img.shape[0] != 0 and mouth_img.shape[1] != 0:
                    resized_array = cv2.resize(mouth_img, (IMG_SIZE, IMG_SIZE))
                    yaw_no.append([resized_array, class_num1])
                else:
                    print("Empty image")
               
                
                
        
    return yaw_no

# %%
IMG_SIZE = 145
image_array = cv2.imread("close9.jpg")
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
faces = face_cascade.detectMultiScale(image_array, 1.3, 5)
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")
for (x, y, w, h) in faces:
    landmarks = predictor(image_array, dlib.rectangle(x,y,x+w,y+h))
    mouth_points = landmarks.parts()[48:68]
    mouth_points_array = []
    for point in mouth_points:
        mouth_points_array.append((point.x, point.y))
    mouth_points_array = np.array(mouth_points_array, dtype=np.int32)
                
                 # Get the bounding rectangle around the mouth region
    x1, y1 = np.min(mouth_points_array, axis=0)
    x2, y2 = np.max(mouth_points_array, axis=0)
                
    mouth_img = image_array[y1:y2, x1:x2]
                
    if mouth_img.shape[0] != 0 and mouth_img.shape[1] != 0:
        resized_array = cv2.resize(mouth_img, (IMG_SIZE, IMG_SIZE))
        plt.imshow(resized_array)
#         yaw_no.append([resized_array, class_num1])

    else:
        print("Empty image")

# %%
yawn_no_yawn = face_for_yawn()
# Out:
# 0
# 1

# %% [markdown]
# ## For Closed and Open eye

# %%
def get_data(dir_path=r"archive\train", face_cas=r"archive(1)\haarcascade_frontalface_default.xml", eye_cas=r"archive(1)\haarcascade.xml"):
    labels = ['Closed', 'Open']
    IMG_SIZE = 145
    data = []
    for label in labels:
        path = os.path.join(dir_path, label)
        class_num = labels.index(label)
        class_num +=2
        print(class_num)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                data.append([resized_array, class_num])
            except Exception as e:
                print(e)
    return data

# %%
data_train = get_data()
# Out:
# 2
# 3

# %% [markdown]
# ## Extend data and Convert array

# %%
def append_data():
#     total_data = []
    yaw_no = face_for_yawn()
    data = get_data()
    yaw_no.extend(data)
    return np.array(yaw_no)

# %% [markdown]
# ## New variable to store

# %%
new_data = append_data()
# Out:
# 0
# 1
# 2
# 3
# C:\Users\HP\AppData\Local\Temp\ipykernel_14988\2804427426.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return np.array(yaw_no)

# %% [markdown]
# ## Separate label and features

# %%
X = []
y = []
for feature, label in new_data:
    X.append(feature)
    y.append(label)

# %% [markdown]
# ## Reshape the Array

# %%
X = np.array(X)
X = X.reshape(-1, 145, 145, 3)

# %% [markdown]
# ## LabelBinarizer

# %%
from sklearn.preprocessing import LabelBinarizer
label_bin = LabelBinarizer()
y = label_bin.fit_transform(y)

# %% [markdown]
# ## Label array

# %%
y = np.array(y)

# %% [markdown]
# ## Train Test split

# %%
from sklearn.model_selection import train_test_split
seed = 42
test_size = 0.30
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=seed, test_size=test_size)

# %% [markdown]
# ## Length of X_test

# %%
len(X_test)
# Out:
# 578

# %% [markdown]
# ## Import some dependencies

# %%
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, Conv2D, MaxPooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf

# %% [markdown]
# ## Data Augmentation

# %%
import numpy as np

train_generator = ImageDataGenerator(rescale=1/255, zoom_range=0.2, horizontal_flip=True, rotation_range=30)
test_generator = ImageDataGenerator(rescale=1/255)




train_generator = train_generator.flow(np.array(X_train), y_train, shuffle=False)
test_generator = test_generator.flow(np.array(X_test), y_test, shuffle=False)

# %% [markdown]
# # Model

# %%
model = Sequential()

model.add(Conv2D(256, (3, 3), activation="relu", input_shape=(145,145,3)))
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(128, (3, 3), activation="relu"))
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(64, (3, 3), activation="relu"))
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(32, (3, 3), activation="relu"))
model.add(MaxPooling2D(2, 2))

model.add(Flatten())
model.add(Dropout(0.5))

model.add(Dense(64, activation="relu"))
model.add(Dense(4, activation="softmax"))

model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer="adam")

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 143, 143, 256)     7168
#
#  max_pooling2d (MaxPooling2D  (None, 71, 71, 256)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 69, 69, 128)       295040
#
#  max_pooling2d_1 (MaxPooling  (None, 34, 34, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        73792
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 32)        18464
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 1568)              0
#
#  dropout (Dropout)           (None, 1568)              0
#
#  dense (Dense)               (None, 64)                100416
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 495,140
# Trainable params: 495,140
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_generator, epochs=50, validation_data=test_generator, shuffle=True, validation_steps=len(test_generator))
# Out:
# Epoch 1/50
# 43/43 [==============================] - 182s 4s/step - loss: 1.1780 - accuracy: 0.4900 - val_loss: 0.7472 - val_accuracy: 0.6817
# Epoch 2/50
# 43/43 [==============================] - 173s 4s/step - loss: 0.6767 - accuracy: 0.7543 - val_loss: 0.5293 - val_accuracy: 0.7664
# Epoch 45/50
# 43/43 [==============================] - 170s 4s/step - loss: 0.0946 - accuracy: 0.9644 - val_loss: 0.1662 - val_accuracy: 0.9585
# Epoch 46/50
# 43/43 [==============================] - 171s 4s/step - loss: 0.0816 - accuracy: 0.9688 - val_loss: 0.2145 - val_accuracy: 0.9567
# Epoch 47/50
# 43/43 [==============================] - 171s 4s/step - loss: 0.0667 - accuracy: 0.9777 - val_loss: 0.2152 - val_accuracy: 0.9533
# Epoch 48/50
# 43/43 [==============================] - 175s 4s/step - loss: 0.0802 - accuracy: 0.9688 - val_loss: 0.1471 - val_accuracy: 0.9654
# Epoch 49/50
# 43/43 [==============================] - 171s 4s/step - loss: 0.0760 - accuracy: 0.9710 - val_loss: 0.1997 - val_accuracy: 0.9602
# Epoch 50/50
# 43/43 [==============================] - 172s 4s/step - loss: 0.0815 - accuracy: 0.9725 - val_loss: 0.2250 - val_accuracy: 0.9637

# %% [markdown]
# ## History

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, "b", label="trainning accuracy")
plt.plot(epochs, val_accuracy, "r", label="validation accuracy")
plt.legend()
plt.show()

plt.plot(epochs, loss, "b", label="trainning loss")
plt.plot(epochs, val_loss, "r", label="validation loss")
plt.legend()
plt.show()

# %% [markdown]
# ## Save Model

# %%
model.save("Final_model.h5")

# %% [markdown]
# # Prediction

# %%
prediction = np.argmax(model.predict(X_test), axis=-1)
# Out:
# 19/19 [==============================] - 20s 967ms/step

# %%
prediction
# Out:
# array([3, 3, 2, 3, 1, 3, 3, 2, 1, 2, 3, 3, 3, 2, 2, 2, 3, 1, 0, 3, 2, 3,
#        2, 1, 1, 2, 2, 2, 3, 2, 3, 2, 3, 2, 1, 3, 3, 2, 1, 3, 3, 3, 2, 3,
#        2, 2, 3, 3, 0, 3, 3, 1, 2, 1, 3, 3, 2, 2, 2, 1, 3, 3, 1, 0, 2, 3,
#        2, 3, 2, 2, 1, 3, 3, 3, 2, 0, 0, 3, 1, 3, 2, 0, 3, 2, 2, 2, 2, 1,
#        3, 2, 2, 3, 3, 3, 1, 0, 3, 0, 3, 3, 3, 1, 3, 1, 2, 3, 0, 1, 2, 2,
#        1, 1, 2, 1, 0, 3, 3, 3, 2, 2, 3, 3, 3, 1, 1, 2, 3, 3, 2, 0, 3, 3,
#        0, 3, 1, 2, 3, 3, 2, 1, 2, 2, 2, 1, 3, 3, 2, 3, 2, 0, 3, 3, 3, 3,
#        3, 1, 1, 0, 3, 1, 3, 2, 2, 3, 2, 3, 3, 2, 3, 2, 3, 1, 2, 0, 3, 3,
#        2, 2, 0, 2, 3, 0, 2, 1, 3, 2, 3, 1, 2, 0, 1, 3, 2, 2, 3, 3, 3, 0,
#        3, 2, 3, 0, 2, 0, 0, 1, 2, 3, 2, 0, 3, 1, 2, 2, 2, 2, 1, 3, 1, 1,
#        1, 0, 2, 3, 3, 3, 3, 0, 1, 2, 1, 0, 3, 3, 0, 3, 3, 0, 3, 3, 0, 1,
#        0, 0, 3, 3, 3, 3, 3, 2, 3, 3, 2, 3, 2, 0, 2, 2, 2, 0, 3, 3, 2, 2,
#        3, 2, 2, 0, 2, 3, 2, 2, 2, 3, 3, 3, 3, 3, 0, 1, 1, 3, 3, 3, 3, 2,
#        2, 1, 2, 2, 2, 3, 2, 0, 2, 2, 1, 3, 2, 3, 1, 3, 3, 1, 3, 3, 0, 3,
#        3, 2, 2, 2, 1, 1, 0, 3, 3, 3, 3, 1, 3, 0, 3, 2, 2, 1, 3, 3, 3, 2,
#        3, 3, 2, 3, 3, 3, 3, 2, 1, 3, 2, 2, 2, 1, 2, 0, 3, 3, 2, 3, 2, 2,
#        2, 2, 3, 0, 0, 2, 1, 0, 2, 2, 2, 1, 3, 2, 3, 3, 3, 2, 2, 2, 2, 2,
#        2, 0, 1, 3, 3, 3, 2, 1, 3, 2, 2, 1, 0, 2, 2, 3, 2, 1, 3, 2, 3, 3,
#        3, 1, 0, 3, 0, 2, 3, 2, 2, 3, 1, 3, 3, 2, 3, 3, 1, 2, 3, 2, 3, 1,
#        1, 3, 2, 2, 3, 1, 3, 2, 2, 3, 3, 2, 1, 2, 1, 1, 2, 2, 1, 3, 2, 3,
#        3, 3, 2, 2, 3, 2, 1, 1, 2, 2, 2, 2, 2, 0, 2, 3, 3, 2, 1, 3, 2, 2,
#        2, 2, 3, 3, 0, 0, 1, 3, 3, 2, 2, 2, 2, 2, 2, 2, 1, 2, 0, 2, 3, 2,
#        2, 2, 2, 3, 2, 3, 3, 2, 3, 2, 3, 2, 3, 1, 0, 2, 2, 3, 2, 3, 0, 1,
#        1, 3, 1, 1, 3, 2, 2, 1, 2, 2, 3, 2, 2, 3, 3, 3, 3, 2, 1, 3, 2, 3,
#        2, 2, 3, 2, 2, 2, 3, 3, 2, 1, 2, 1, 3, 3, 1, 0, 3, 3, 3, 2, 2, 0,
#        3, 2, 2, 2, 2, 2, 2, 3, 2, 0, 1, 3, 2, 2, 3, 3, 2, 3, 2, 3, 2, 2,
#        3, 2, 2, 3, 2, 2], dtype=int64)

# %% [markdown]
# # classification report

# %%
labels_new = ["yawn", "no_yawn", "Closed", "Open"]

# %%
from sklearn.metrics import classification_report
print(classification_report(np.argmax(y_test, axis=1), prediction, target_names=labels_new))
# Out:
#               precision    recall  f1-score   support
#
#         yawn       0.86      0.76      0.81        63
#      no_yawn       0.84      0.97      0.90        74
#       Closed       0.97      0.97      0.97       215
#         Open       0.99      0.97      0.98       226
#
#     accuracy                           0.95       578
#    macro avg       0.91      0.92      0.91       578
# weighted avg       0.95      0.95      0.95       578

# %% [markdown]
# # Detecting eyes

# %%
import matplotlib.pyplot as plt
import cv2
img = cv2.imread("close9.jpg")


FaceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

eyes = eye_cascade.detectMultiScale(gray, 1.1, 4)

for (x,y,w,h) in eyes:
     cv2.rectangle(img, (x,y), (x+w, y+h), (0, 255,0), 2)
        
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # predicting function  (2 for closed and 3 for open)

# %%
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf


def prepare(filepath):
    img = cv2.imread(filepath)
    eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    eyes = eye_cascade.detectMultiScale(gray, 1.4, 1)
    IMG_SIZE = 145
    
    for x,y,w,h in eyes:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
#         if len(eyes) == 0:
#             print("eyes not detected")
        
#         else:
        for(ex,ey,ew,eh) in eyes:
            eyes_roi = roi_color[ey: ey+eh, ex:ex + ew]
             
    
    img_array = cv2.resize(eyes_roi, (IMG_SIZE, IMG_SIZE))  
    img_array = img_array / 255
    image = img_array.reshape(-1, IMG_SIZE, IMG_SIZE, 3)  

    plt.imshow(img_array)
    img_array.shape
    return image



model = tf.keras.models.load_model("Final_model.h5")

# %%
prediction = model.predict([prepare("close9.jpg")])
np.argmax(prediction)
# Out:
# 1/1 [==============================] - 0s 203ms/step
# 2

# %%
prediction = model.predict([prepare("face.jpg")])
np.argmax(prediction)
# Out:
# 1/1 [==============================] - 0s 83ms/step
# 3

# %%
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf


def prepare(filepath):
    img = cv2.imread(filepath)
    eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    eyes = eye_cascade.detectMultiScale(gray, 1.4, 1)
    IMG_SIZE = 145
    
    for x,y,w,h in eyes:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
#         if len(eyes) == 0:
#             print("eyes not detected")
        
#         else:
        for(ex,ey,ew,eh) in eyes:
            eyes_roi = roi_color[ey: ey+eh, ex:ex + ew]
             
    
    img_array = cv2.resize(eyes_roi, (IMG_SIZE, IMG_SIZE))  
    img_array = img_array / 255
    image = img_array.reshape(-1, IMG_SIZE, IMG_SIZE, 3)  

    plt.imshow(img_array)
    img_array.shape
    return image



model = tf.keras.models.load_model("Final_model.h5")

# %%
prediction = model.predict([prepare("Testing_images/pic2.jpg")])
np.argmax(prediction)
# Out:
# 1/1 [==============================] - 0s 94ms/step
# 2

# %%
prediction = model.predict([prepare("Testing_images/pic3.jpg")])
np.argmax(prediction)
# Out:
# 1/1 [==============================] - 0s 85ms/step
# 2

# %%
prediction = model.predict([prepare("Testing_images/pic4.jpg")])
np.argmax(prediction)
# Out:
# 1/1 [==============================] - 0s 91ms/step
# 3

# %%
import numpy as np
prediction = model.predict([prepare("Testing_images/pic8.jpg")])
np.argmax(prediction)
# Out:
# 1/1 [==============================] - 0s 81ms/step
# 0

# %% [markdown]
# # Prediction function for mouth (0 for yawn and 1 for no yawn)

# %%
def prepareForMouth(filepath):
    # Load the image
    img = cv2.imread(filepath)
    # Load the face detection cascade classifier
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    # Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Detect the face in the image
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    IMG_SIZE = 145
    # Load the facial landmark detector
    predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")

# Loop over all the detected faces
    for (x,y,w,h) in faces:
        # Get the facial landmarks for the face region
        landmarks = predictor(gray, dlib.rectangle(x,y,x+w,y+h))
        mouth_points = landmarks.parts()[48:68]
        # Convert the mouth landmarks to a numpy array
        mouth_points_array = []
        for point in mouth_points:
            mouth_points_array.append((point.x, point.y))
        mouth_points_array = np.array(mouth_points_array, dtype=np.int32)
    
        # Get the bounding rectangle around the mouth region
        x1, y1 = np.min(mouth_points_array, axis=0)
        x2, y2 = np.max(mouth_points_array, axis=0)
    
        # Crop the mouth region from the image
        mouth_img = img[y1:y2, x1:x2]
        
        
        #Preprocess image to feed to model
        mouth_img = cv2.resize(mouth_img, (IMG_SIZE, IMG_SIZE))  
        mouth_img = mouth_img / 255
        image1 = mouth_img.reshape(-1, IMG_SIZE, IMG_SIZE, 3)  
        
        
        plt.imshow(mouth_img)
    return image1

model = tf.keras.models.load_model("Final_model.h5")

# %%
prediction = model.predict([prepareForMouth("face.jpg")])
np.argmax(prediction)
# Out:
# 1/1 [==============================] - 0s 209ms/step
# 1

# %%
prediction = model.predict([prepareForMouth("archive/train/yawn/10.jpg")])
np.argmax(prediction)
# Out:
# 1/1 [==============================] - 0s 94ms/step
# 0

# %%
prediction = model.predict([prepareForMouth("Testing_images/pic7.jpg")])
np.argmax(prediction)
# Out:
# 1/1 [==============================] - 0s 85ms/step
# 0

# %% [markdown]
# # Convert model to tflite

# %%
import tensorflow as tf

# Load the Keras .h5 model
keras_model = tf.keras.models.load_model('Final_model.h5')

# Convert the Keras model to a TensorFlow Lite model
converter = tf.lite.TFLiteConverter.from_keras_model(keras_model)
tflite_model = converter.convert()

# Save the converted model to disk
open('Final_model.tflite', 'wb').write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\HP\AppData\Local\Temp\tmpg9_tex0t\assets
# INFO:tensorflow:Assets written to: C:\Users\HP\AppData\Local\Temp\tmpg9_tex0t\assets
# 1985312

# %% [markdown]
# # Loading model

# %%
import cv2     #this
import numpy as np
import winsound
from keras.models import load_model
from keras.utils.image_utils import img_to_array


classes = ['Closed', 'Open']
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
left_eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +"haarcascade_lefteye_2splits.xml")
right_eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_righteye_2splits.xml")
cap = cv2.VideoCapture(0)
model = load_model("drowiness_new7.h5") #drowiness_model.h5
count = 0
status1 = ''
status2 = ''

while True:
    _, frame = cap.read()
#     height = frame.shape[0]
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 255, 255), 1)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = frame[y:y+h, x:x+w]
        left_eye = left_eye_cascade.detectMultiScale(roi_gray)
        right_eye = right_eye_cascade.detectMultiScale(roi_gray)
        for (x1, y1, w1, h1) in left_eye:
            cv2.rectangle(roi_color, (x1, y1), (x1 + w1, y1 + h1), (255, 255, 255), 1)
            eye1 = roi_color[y1:y1+h1, x1:x1+w1]
            eye1 = cv2.resize(eye1, (145, 145))
            eye1 = eye1.astype('float') / 255.0
            eye1 = img_to_array(eye1)
            eye1 = np.expand_dims(eye1, axis=0)
            pred1 = model.predict(eye1)
            status1=np.argmax(pred1)
            break

        for (x2, y2, w2, h2) in right_eye:
            cv2.rectangle(roi_color, (x2, y2), (x2 + w2, y2 + h2), (255, 255, 255), 1)
            eye2 = roi_color[y2:y2 + h2, x2:x2 + w2]
            eye2 = cv2.resize(eye2, (145, 145))
            eye2 = eye2.astype('float') / 255.0
            eye2 = img_to_array(eye2)
            eye2 = np.expand_dims(eye2, axis=0)
            pred2 = model.predict(eye2)
            status2=np.argmax(pred2)
            break

        # If the eyes are closed, start counting
        if status1 == 2 and status2 == 2:
        #if pred1 == 2 and pred2 == 2:
            count += 1
            cv2.putText(frame, "Eyes Closed, Frame count: " + str(count), (10, 30), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 255), 1)
            # if eyes are closed for 10 consecutive frames, start the alarm
            if count >= 10:
                while (status1 == 2 and status2 == 2):
                    winsound.PlaySound("newA", winsound.SND_FILENAME)
                    break
                cv2.putText(frame, "Drowsiness Alert!!!", (100, height-20), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 255), 2)
                break

        else:
            cv2.putText(frame, "Eyes Open", (10, 30), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 255, 0), 1)
            count = 0
            alarm_on = False

    cv2.imshow("Drowsiness Detector", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 85ms/step
